# %%
import time
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup
from random import randint
from time import sleep

# %%
standings_url = "https://fbref.com/en/comps/20/Bundesliga-Stats"
#standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Dortmund                                                          \
#           Date   Time        Comp        Round  Day Venue Result GF GA
# 0   2022-07-29  20:45   DFB-Pokal  Round of 64  Fri  Away      W  3  0
# 1   2022-08-06  18:30  Bundesliga  Matchweek 1  Sat  Home      W  1  0
# 2   2022-08-12  20:30  Bundesliga  Matchweek 2  Fri  Away      W  3  1
# 3   2022-08-20  15:30  Bundesliga  Matchweek 3  Sat  Home      L  2  3
# 4   2022-08-27  15:30  Bundesliga  Matchweek 4  Sat  Away      W  1  0
#
#                   ... Standard               Expected                    \
#         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0    1860 Munich  ...      NaN  NaN  0     0      NaN  NaN     NaN  NaN
# 1     Leverkusen  ...     16.0  1.0  0     0      1.5  1.5    0.12 -0.5
# 2       Freiburg  ...     19.7  1.0  0     0      1.3  1.3    0.10  1.7
# 3  Werder Bremen  ...     19.7  0.0  0     0      0.6  0.6    0.11  1.4
# 4     Hertha BSC  ...     13.6  1.0  0     0      3.0  3.0    0.13 -2.0
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0     NaN        Match Report
# 1    -0.5        Match Report
# 2     1.7        Match Report
# 3     1.4        Match Report
# 4    -2.0        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time        Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-07-29  20:45   DFB-Pokal  Round of 64  Fri  Away      W  3.0  0.0
# 1  2022-08-06  18:30  Bundesliga  Matchweek 1  Sat  Home      W  1.0  0.0
# 2  2022-08-12  20:30  Bundesliga  Matchweek 2  Fri  Away      W  3.0  1.0
# 3  2022-08-20  15:30  Bundesliga  Matchweek 3  Sat  Home      L  2.0  3.0
# 4  2022-08-27  15:30  Bundesliga  Matchweek 4  Sat  Away      W  1.0  0.0
#
#         Opponent  ...  Formation             Referee  Match Report  Notes  Sh  \
# 0    1860 Munich  ...    4-2-3-1      Benjamin Brand  Match Report    NaN  25
# 1     Leverkusen  ...      4-3-3         Felix Brych  Match Report    NaN  14
# 2       Freiburg  ...    4-2-3-1         Tobias Welz  Match Report    NaN  13
# 3  Werder Bremen  ...    4-2-3-1  Florian Badstübner  Match Report    NaN   6
# 4     Hertha BSC  ...    4-2-3-1      Tobias Stieler  Match Report    NaN  23
#
#   SoT  Dist   FK  PK  PKatt
# 0  11   NaN  NaN   0      0
# 1   4  16.0  1.0   0      0
# 2   6  19.7  1.0   0      0
# 3   4  19.7  0.0   0      0
# 4   7  13.6  1.0   0      0
#
# [5 rows x 25 columns]
